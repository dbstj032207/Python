# %% [markdown]
# ### 참고 사이트
#
# + https://matplotlib.org
# + https://seaborn.pydata.org

# %% [markdown]
# ## 1. 기본 그래프(basic plot)
#
# 막대(bar), 선(line), 산포도(산점도, scatter plot), 히스토그램, 상자(box)

# %% [markdown]
# ### (1) 질적 데이터
#
# + 요약방법 : 도표
# + 정리방법 : 도수 분포표, 분할표
# + 그래프 : 막대, 원, ...
#
#
# ### (2) 양적 데이터
#
# + 요약방법 : 수치
# + 정리방법 : 산술평균, 중앙값, ...
# + 그래프 : 히스토그램, 선(시계열 데이터), 산포도, Boxplot, ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mlp
mlp.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## 2. 선 그래프

# %%
s = pd.Series(np.random.randn(10), index=np.arange(0, 100, 10))
s

s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=["가", "나", "다", "라"],
                 index=np.arange(0, 100, 10))
df.plot()
df.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3. 막대 그래프

# %%
s = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
s

s.plot(kind="bar")
s.plot.bar()
# Out:
# <AxesSubplot:>

# %%
s.plot(kind="barh")
s.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=["one", "two", "three",
                                              "four", "five", "six"],
                 columns=["A", "B", "C", "D"])

df
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6, 4), index=["one", "two", "three",
                                              "four", "five", "six"],
                 columns=pd.Index(["A", "B", "C", "D"], name="성적"))

df
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar", stacked= True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="barh", stacked= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. 히스토그램
#
# + 값만 필요하고 인덱스는 필요없다.
# + 숫자 형태의 데이터값을 범주형 변수로 활용할 때 사용

# %%
s = pd.Series(np.random.normal(0, 1, size=100))
s

s.hist()
# Out:
# <AxesSubplot:>

# %%
s.hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. 산점도(산포도, scatter plot)
#
# + 두 변수의 관계를 확인

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x1

x2 = np.random.normal(-2, 4, size=(100, 1))
x2

x = np.concatenate((x1, x2), axis = 1)
x[:5]

df = pd.DataFrame(x, columns=["x1", "x2"])
df

df.plot.scatter("x1", "x2")
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# ## 상자 그래프(box plot)\
#
# + five-number summary
#     - 최소값, 최대값, 1사분위, 2사분위, 3사분위

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 7. 활용 예제
# + tips 샘플

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
##### total_bill에 대한 금액 분포 확인

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.hist(tips["total_bill"], bins=30)
ax.set_title("식사 대금에 대한 히스토그램")
ax.set_xlabel("frequency")
ax.set_ylabel("Total Bill")
# Out:
# Text(0.5, 1.0, '식사 대금에 대한 히스토그램')

# %%
##### total_bill 과 tip의 관계를 알고 싶다.

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(tips["total_bill"], tips.tip)
ax.set_title("식사 대금과 팁에 대한 히스토그램")
ax.set_xlabel("Total_Bill")
ax.set_ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %%
##### 성별과 팁의 관계

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.boxplot([tips[tips["sex"]==["Male"]["tip"], 
            tips[tips["sex"]==["Female"]["tip"]], labels=["남성", "여성"])
# Out:
#   Input In [68]
#     tips[tips["sex"]==["Female"]["tip"]], labels=["남성", "여성"])
#                                                 ^
# SyntaxError: invalid syntax

# %%
##### 성별에 따른 total_bill과 tip의 관계를 알고 싶다.

def record_sex(sex):
    if sex == "Female":
        return 0
    else:
        return 1

tips["sex_color"] = tips["sex"].apply(record_sex)
tips.head(10)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(tips["total_bill"], tips["tip"], c=tips["sex_color"],
          alpha=0.7, s=tips["size"]*10)

# %% [markdown]
# ## 8. 활용 예제2
#
# + 전국 신규 민간아파트 분양 가격 동향
# + https://data.go.kr

# %% [markdown]
# ### (1) Data Definition

# %%
apt = pd.read_csv("data/20200331.csv", encoding="euc-kr")
apt.head(10)
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울                 전체  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879
# 5  인천                 전체  2015  10    3163
# 6  인천         전용면적 60㎡이하  2015  10    3488
# 7  인천   전용면적 60㎡초과 85㎡이하  2015  10    3119
# 8  인천  전용면적 85㎡초과 102㎡이하  2015  10    3545
# 9  인천        전용면적 102㎡초과  2015  10    3408

# %% [markdown]
# ### (2) Data Preprocessing

# %%
##### Column의 이름을 영어로 변경(city, size, year, month, price)

apt1 = apt[:]
apt1.columns = ["city", "size", "year", "month", "price"]
apt1.head()
# Out:
#   city               size  year  month price
# 0   서울                 전체  2015     10  5841
# 1   서울         전용면적 60㎡이하  2015     10  5652
# 2   서울   전용면적 60㎡초과 85㎡이하  2015     10  5882
# 3   서울  전용면적 85㎡초과 102㎡이하  2015     10  5721
# 4   서울        전용면적 102㎡초과  2015     10  5879

# %%
apt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4590 entries, 0 to 4589
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    4590 non-null   object
#  1   size    4590 non-null   object
#  2   year    4590 non-null   int64
#  3   month   4590 non-null   int64
#  4   price   4276 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 179.4+ KB

# %%
##### price는 숫자로 데이터 타입 변경
apt1["price"] = pd.to_numeric(apt1["price"].str.strip())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4590 entries, 0 to 4589
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    4590 non-null   object
#  1   size    4590 non-null   object
#  2   year    4590 non-null   int64
#  3   month   4590 non-null   int64
#  4   price   4260 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 179.4+ KB

# %%
apt1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4590 entries, 0 to 4589
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    4590 non-null   object
#  1   size    4590 non-null   object
#  2   year    4590 non-null   int64
#  3   month   4590 non-null   int64
#  4   price   4260 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 179.4+ KB

# %% [markdown]
# ### (3) Visualization

# %%
##### 서울과 전체 사이즈만 조회

apt1_seoul = apt1[(apt1["city"] == "서울") & (apt1["size"] == "전체")]

# apt1.query('(city=="서울") and (size=="전체")')

# %%
apt1_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 4505
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    54 non-null     object
#  1   size    54 non-null     object
#  2   year    54 non-null     int64
#  3   month   54 non-null     int64
#  4   price   54 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.5+ KB

# %%
##### city, size 컬럼 삭제하고 year롸 month는 다중 index로 

apt1_seoul1 = apt1_seoul[:]
# del apt1_seoul1["city"]
# del apt1_seoul1["size"]

apt1_seoul1 = apt1_seoul1.drop(["city", "size"], axis=1)
apt1_seoul1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 4505
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    54 non-null     int64
#  1   month   54 non-null     int64
#  2   price   54 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 1.7 KB

# %%
apt1_seoul1 = apt1_seoul1.set_index(["year", "month"])

# %%
apt1_seoul1.plot()
# Out:
# <AxesSubplot:xlabel='year,month'>

# %% [markdown]
# ## 9.Seaborn

# %%
tips = sns.load_dataset("tips")

# %%
##### total_bill에 대한 금액 분포 환인

sns.distplot(tips["total_bill"])
# Out:
# C:\Users\dbs03\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(tips["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
##### 요일별로 인원 수 파악
sns.countplot("day", data=tips)
# Out:
# C:\Users\dbs03\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
##### total_bill과 tip의 관계를 알고 싶다

sns.regplot(x="total_bill", y="tip", data = tips, fit_reg=False)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x="total_bill", y="tip", data=tips)

# %%
sns.kdeplot(x="total_bill", y="tip", data=tips, shade=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
##### 시간에 따른 식사대금
sns.barplot(x="time", y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.boxplot(x="time", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.violinplot(x="time", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.pairplot(tips)

# %%
##### 성별에 따른 total_bill과 tip의 관계를 알고 싶다.

sns.lmplot(x="total_bill", y="tip", data=tips, fit_reg=False, 
           hue="sex", markers=["o", "x"])

# %% [markdown]
# ## 10. 활용 예제3
#
# + 타이타닉
#     - https://www.kaggle.com/c/titanic

# %% [markdown]
# ### (1) Data Prepare

# %%
train = pd.read_csv("data/train.csv")
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## (2) EDA(Explorer Data Analysis)

# %%
def bar_chart(feature):
    survived = train[train["Survived"] == 1][feature].value_counts()
    dead = train[train["Survived"] == 0][feature].value_counts()
    
    df = pd.DataFrame([survived, dead])
    df.index = ["Survived", "Dead"]
    df.plot(kind="bar", stacked=True)

# %%
train[train["Survived"] == 1]["Sex"].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
bar_chart("Sex")

# %%
bar_chart("Pclass")

# %%
bar_chart("SibSp")

# %%
bar_chart("Parch")

# %%
bar_chart("Embarked")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
##### Name에서 호칭 부분 추출하기

train["title"] = train["Name"].str.extract(" ([a-zA-Z]+)\.")
train["title"].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: title, dtype: int64

# %%
bar_chart("title")

# %%
title_mapping = {"Mr":0,
"Miss":1,
"Mrs":2,
"Master":3,
"Dr":3,
"Rev":3,
"Mlle":3,
"Major":3,
"Col":3,
"Countess":3,
"Capt":3,
"Ms":3,
"Sir":3,
"Lady":3,
"Mme":3,
"Don":3,
"Jonkheer":3   
}
train["title"] = train["title"].map(title_mapping)
train["title"].value_counts()
# Out:
# 0    517
# 1    182
# 2    125
# 3     67
# Name: title, dtype: int64

# %%
train["Age"].fillna(train.groupby("title")["Age"].transform("mean"), inplace=True)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  title        891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
facet = sns.FacetGrid(train, hue="Survived", aspect=4)
facet.map(sns.kdeplot, "Age", shade=True)
facet.add_legend()
# facet.set(xlim=(0, train["Age"].max()))
facet.set(xlim=(10, 30))

# %% [markdown]
# ## 11. 지도 시각화
#
# + pip install folium

# %%
import folium

# %%
folium.Map(location=[37.497955, 127.027619], zoom_start=15, tiles="Stamen Toner")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_957493df433baa79e1df7c2ea65aa7cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_957493df433baa79e1df7c2ea65aa7cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_957493df433baa79e1df7c2ea65aa7cf = L.map(
#                 &quot;map_957493df433baa79e1df7c2ea65aa7cf&quot;,
#                 {
#                     center: [37.497955, 127.027619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a2a5adc21c4418878e956719c96326b = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_957493df433baa79e1df7c2ea65aa7cf);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[40, -98], zoom_start=4)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2377ac50135cce2c257e5dded6888a2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2377ac50135cce2c257e5dded6888a2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2377ac50135cce2c257e5dded6888a2f = L.map(
#                 &quot;map_2377ac50135cce2c257e5dded6888a2f&quot;,
#                 {
#                     center: [40.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_760425d8fe6c99daab8bbb1c319bfbdc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2377ac50135cce2c257e5dded6888a2f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
##### 미국 50개주의 실업률 표시

state_unemp = pd.read_csv("data/map/folium_US_Unemployment_Oct2012.csv")
state_unemp.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
state_geo = "data/map/folium_us-states.json"
state_geo
map.choropleth(geo_data=state_geo, 
               data=state_unemp, 
               key_on="feature.id", 
               columns=["State", "Unemployment"],
               fill_color="YlGn")
map
# Out:
# C:\Users\dbs03\anaconda3\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2377ac50135cce2c257e5dded6888a2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2377ac50135cce2c257e5dded6888a2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2377ac50135cce2c257e5dded6888a2f = L.map(
#                 &quot;map_2377ac50135cce2c257e5dded6888a2f&quot;,
#                 {
#                     center: [40.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_760425d8fe6c99daab8bbb1c319bfbdc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2377ac50135cce2c257e5dded6888a2f);
#
#
#             var choropleth_4f354d4446c893354e801232a3b8e0e2 = L.featureGroup(
#                 {}
#             ).addTo(map_2377ac50135cce2c257e5dded6888a2f);
#
#
#         function geo_json_01d2587d5c31167ef72e388ccc256bc0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;NE&quot;: case &quot;ND&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_01d2587d5c31167ef72e388ccc256bc0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_01d2587d5c31167ef72e388ccc256bc0 = L.geoJson(null, {
#                 onEachFeature: geo_json_01d2587d5c31167ef72e388ccc256bc0_onEachFeature,
#
#                 style: geo_json_01d2587d5c31167ef72e388ccc256bc0_styler,
#         });
#
#         function geo_json_01d2587d5c31167ef72e388ccc256bc0_add (data) {
#             geo_json_01d2587d5c31167ef72e388ccc256bc0
#                 .addData(data)
#                 .addTo(choropleth_4f354d4446c893354e801232a3b8e0e2);
#         }
#             geo_json_01d2587d5c31167ef72e388ccc256bc0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alabama&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordina

# %%
##### Marking
map = folium.Map(location=[37.497955, 127.027619], zoom_start=15)
map

marker = folium.Marker(location=[37.497955, 127.027619],
             icon=folium.Icon(color="red", icon="star"), 
                      popup="강남역에서 12시에 약속")

marker.add_to(map)
map

folium.CircleMarker(location=[37.497955, 127.027619], radius=50,
                   color="#ffffgg", fill_color="#fffggg").add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72d4a688c8e544ab63f80a5db9e73a20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72d4a688c8e544ab63f80a5db9e73a20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_72d4a688c8e544ab63f80a5db9e73a20 = L.map(
#                 &quot;map_72d4a688c8e544ab63f80a5db9e73a20&quot;,
#                 {
#                     center: [37.497955, 127.027619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c40f03c5d3109d05e843d29f96c36f7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_72d4a688c8e544ab63f80a5db9e73a20);
#
#
#             var marker_c59c85fa0b2b505330b3d5957c8def51 = L.marker(
#                 [37.497955, 127.027619],
#                 {}
#             ).addTo(map_72d4a688c8e544ab63f80a5db9e73a20);
#
#
#             var icon_add1c9ad269af6bd538f901ca86b1f87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c59c85fa0b2b505330b3d5957c8def51.setIcon(icon_add1c9ad269af6bd538f901ca86b1f87);
#
#
#         var popup_cb5fdd0b872cd7546c364f5dbd5dd62d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a5fb6b5bbe0b3ad44c3a9b5e1799d487 = $(`&lt;div id=&quot;html_a5fb6b5bbe0b3ad44c3a9b5e1799d487&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남역에서 12시에 약속&lt;/div&gt;`)[0];
#             popup_cb5fdd0b872cd7546c364f5dbd5dd62d.setContent(html_a5fb6b5bbe0b3ad44c3a9b5e1799d487);
#
#
#         marker_c59c85fa0b2b505330b3d5957c8def51.bindPopup(popup_cb5fdd0b872cd7546c364f5dbd5dd62d)
#         ;
#
#
#
#
#             var circle_marker_3ea5767b53e73aaae0da455a50f4e6c5 = L.circleMarker(
#                 [37.497955, 127.027619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffgg&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fffggg&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_72d4a688c8e544ab63f80a5db9e73a20);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.497955, 127.027619], zoom_start=15)
map

text = "많은양의 데이터가 있다고 가정"
iframe = folium.IFrame(text, width=300, height=200)
pop = folium.Popup(iframe, max_width=3000)


folium.Marker(location=[37.497955, 127.027619],
             icon=folium.Icon(color="red", icon="star"), 
                      popup=pop).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_944c92ae55235788e31306b877cac1e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_944c92ae55235788e31306b877cac1e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_944c92ae55235788e31306b877cac1e4 = L.map(
#                 &quot;map_944c92ae55235788e31306b877cac1e4&quot;,
#                 {
#                     center: [37.497955, 127.027619],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff42942d72833fa0d6d91f5c2a4dfade = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_944c92ae55235788e31306b877cac1e4);
#
#
#             var marker_aac80ca425e2867b351bddd3805d4654 = L.marker(
#                 [37.497955, 127.027619],
#                 {}
#             ).addTo(map_944c92ae55235788e31306b877cac1e4);
#
#
#             var icon_84c62a59fd764577e57d78ef14d018fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aac80ca425e2867b351bddd3805d4654.setIcon(icon_84c62a59fd764577e57d78ef14d018fc);
#
#
#         var popup_2f49fb01bc1b8e178b97c318939cc56e = L.popup({&quot;maxWidth&quot;: 3000});
#
#
#             var i_frame_2e0555c63d01f68f926536d5e7dc9725 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICDrp47snYDslpHsnZgg642w7J207YSw6rCAIOyeiOuLpOqzoCDqsIDsoJU=&quot; width=&quot;300&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_2f49fb01bc1b8e178b97c318939cc56e.setContent(i_frame_2e0555c63d01f68f926536d5e7dc9725);
#
#
#         marker_aac80ca425e2867b351bddd3805d4654.bindPopup(popup_2f49fb01bc1b8e178b97c318939cc56e)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 12. 워드 클라우드
# + pip install wordcloud
#     - 설치가 잘 안될 때는 직접 다운로드 받아서 설치
#     - https://www.lfd.uci.edu/~gohlke/pythonlibs/#_wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
text = open("data/wordcloud/constitution.txt")
text = text.read()
text

wc = WordCloud().generate(text)   # 단어를 추출하여 빈도 수 계산
wc.words_

plt.figure(figsize=(12, 12))
plt.imshow(wc)

# %%
wc = WordCloud(max_font_size=40).generate(text)
plt.figure(figsize=(12, 12))
plt.imshow(wc)

# %%
wc = WordCloud(max_font_size=40, background_color="white").generate(text)
plt.figure(figsize=(12, 12))
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(max_font_size=40, background_color="white").generate(text)
plt.figure(figsize=(12, 12))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
import PIL

# %%
PIL.Image.open("data/wordcloud/alice_mask.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480 at 0x20335904310>

# %%
alice_mask = np.array(PIL.Image.open("data/wordcloud/alice_mask.png"))
alice_mask.shape

plt.figure(figsize=(8, 8))
plt.imshow(alice_mask)

# %%
text2 = open("data/wordcloud/alice.txt")

wc2 = WordCloud().generate(text2)  

plt.figure(figsize=(12, 12))
plt.imshow(wc2)
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 3>()
#       1 text2 = open("data/wordcloud/alice.txt", encoding="UTF-8")
# ----> 3 wc2 = WordCloud().generate(text2)
#       5 plt.figure(figsize=(12, 12))
#       6 plt.imshow(wc2)
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:632, in WordCloud.generate(self, text)
#     617 def generate(self, text):
#     618     """Generate wordcloud from text.
#     619
#     620     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     630     self
#     631     """
# --> 632     return self.generate_from_text(text)
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:613, in WordCloud.generate_from_text(self, text)
#     596 def generate_from_text(self, text):
#     597     """Generate wordcloud from text.
#     598
#     599     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     611     self
#     612     """
# --> 613     words = self.process_text(text)
#     614     self.generate_from_frequencies(words)
#     615     return self
#
# File ~\anaconda3\lib\site-packages\wordcloud\wordcloud.py:575, in WordCloud.process_text(self, text)
#     572 pattern = r"\w[\w']*" if self.min_word_length <= 1 else r"\w[\w']+"
#     573 regexp = self.regexp if self.regexp is not None else pattern
# --> 575 words = re.findall(regexp, text, flags)
#     576 # remove 's
#     577 words = [word[:-2] if word.lower().endswith("'s") else word
#     578          for word in words]
#
# File ~\anaconda3\lib\re.py:241, in findall(pattern, string, flags)
#     233 def findall(pattern, string, flags=0):
#     234     """Return a list of all non-overlapping matches in the string.
#     235
#     236     If one or more capturing groups are present in the pattern, return
#    (...)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object
